# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_parquet('../data/customers_dashboard.parquet')
print(df.head(5))
# Out:
#                                          customer_id  age club_member_status  \
# 0  00000dbacae5abe5e23885899a1fa44253a17956c6d1c3...   49             ACTIVE
# 1  0000423b00ade91418cceaf3b26c6af3dd342b51fd051e...   25             ACTIVE
# 2  000058a12d5b43e67d225668fa1f8d618c13dc232df0ca...   24             ACTIVE
# 3  00005ca1c9ed5f5146b52ac8639a40ca9d57aeff4d1bd2...   54             ACTIVE
# 4  00006413d8573cd20ed7128e53b7b13819fe5cfc2d801f...   52             ACTIVE
#
#   fashion_news_frequency last_purchase  purchase_count  total_spent  \
# 0                   NONE    2020-09-05              21     0.648983
# 1                   NONE    2020-07-08              86     2.601932
# 2                   NONE    2020-09-15              18     0.704780
# 3                   NONE    2019-06-09               2     0.060983
# 4              Regularly    2020-08-12              13     0.469695
#
#    days_since_last_purchase
# 0                        17
# 1                        76
# ...

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1362281 entries, 0 to 1362280
# Data columns (total 8 columns):
#  #   Column                    Non-Null Count    Dtype
# ---  ------                    --------------    -----
#  0   customer_id               1362281 non-null  object
#  1   age                       1362281 non-null  int64
#  2   club_member_status        1356227 non-null  object
#  3   fashion_news_frequency    1346281 non-null  object
#  4   last_purchase             1362281 non-null  datetime64[us]
#  5   purchase_count            1362281 non-null  int64
#  6   total_spent               1362281 non-null  float64
#  7   days_since_last_purchase  1362281 non-null  int64
# dtypes: datetime64[us](1), float64(1), int64(3), object(3)
# memory usage: 83.1+ MB
#                 age               last_purchase  purchase_count   total_spent  \
# count  1.362281e+06                     1362281    1.362281e+06  1.362281e+06
# ...

# %%
df['club_member_status'].unique()
# Out:
# array(['ACTIVE', None, 'PRE-CREATE', 'LEFT CLUB'], dtype=object)

# %%
df[df['club_member_status'].isna() & df['fashion_news_frequency']=='Monthly']
# Out:
# Empty DataFrame
# Columns: [customer_id, age, club_member_status, fashion_news_frequency, last_purchase, purchase_count, total_spent, days_since_last_purchase]
# Index: []

# %%
df[(df['fashion_news_frequency'] == 'Monthly') & (df['club_member_status'].isna())]
# Out:
#                                               customer_id  age  \
# 277771  3434af0aef74ccaad677a777ddebc49ab69575f6db0a8f...   43
# 343304  40a5b175c7de5c68a23d3cf967e4b4236e5462a6c5b714...   56
# 356359  431db2b0652cfcc255f0312060442ebd46e6955e03c8cf...   43
# 371639  45fec77a87ca372f03b944394b4560580a3bd806a7aa30...   56
# 772407  9139c57e9331dcc97b3d94c1b2eb040152d67f85b74cf7...   27
#
#        club_member_status fashion_news_frequency last_purchase  \
# 277771               None                Monthly    2018-10-06
# 343304               None                Monthly    2018-10-11
# 356359               None                Monthly    2018-09-29
# 371639               None                Monthly    2020-03-29
# 772407               None                Monthly    2018-10-15
#
#         purchase_count  total_spent  days_since_last_purchase
# 277771               5     0.096525                       717
# 343304               1     0.101678                       712
# ...

# %%
df['fashion_news_frequency'].unique()
# Out:
# array(['NONE', 'Regularly', None, 'Monthly'], dtype=object)

# %%
df[df['fashion_news_frequency'].isna()]
# Out:
#                                                customer_id  age  \
# 5        000064249685c11552da43ef22a5030f35a147f723d5b0...   -1
# 37       0001bc8e81a72aaf228a103a85d2ac530c09defffbc6ab...   60
# 196      0008383d133df1285f2f3d28ef5f50916630069d3a5c7f...   25
# 367      0011de63f72ba2f8802076bfd5659485012feb52cd0f49...   30
# 396      0012d74ac44959de7ae07dc0fda7e82afff92189196522...   23
# ...                                                    ...  ...
# 1361981  fff15f528e303627d0dc8b0e9a69fd878a05085b42e72a...   32
# 1362009  fff2e1f1cd77950a5116764cb5fe856d9a4b80fc17a1a1...   28
# 1362014  fff2f4f6d84297f48bed3ad3b1b37574536f1d41afbee4...   21
# 1362091  fff67693cb122cc9a939988a5e2194c044e0881b3f1d5f...   33
# 1362132  fff8798d2d4c947004bb562d7959954fcd58bc658a6e24...   22
#
#         club_member_status fashion_news_frequency last_purchase  \
# 5                     None                   None    2019-10-02
# 37                  ACTIVE                   None    2019-11-29
# ...

# %%
df.iloc[371639]['customer_id']
# Out:
# '45fec77a87ca372f03b944394b4560580a3bd806a7aa30c6418c909ea3acf98e'

# %%
for col in ["days_since_last_purchase", "purchase_count", "total_spent"]:
    print(col, "고유값 비율:", df[col].nunique() / len(df))
# Out:
# days_since_last_purchase 고유값 비율: 0.0005388022001334527
# purchase_count 고유값 비율: 0.000548345018391947
# total_spent 고유값 비율: 0.36865888902509836
